# %%
import sys
sys.path.append("../src")
from generate_data import X_filled

X_filled.head(10)
# Out:
# (1567, 590)
# (1567,)
# class
# -1    1463
#  1     104
# Name: count, dtype: int64
# 41951
# Attribute 158    1429
# Attribute 293    1429
# Attribute 294    1429
# Attribute 159    1429
# Attribute 493    1341
# Attribute 359    1341
# Attribute 86     1341
# Attribute 221    1341
# Attribute 247    1018
# Attribute 110    1018
# dtype: int64
# dropped 28 columns with more than 50% missing data
# (1567, 562)
# 0
#    Attribute 1  Attribute 2  Attribute 3  Attribute 4  Attribute 5  \
# 0      3030.93      2564.00    2187.7333    1411.1265       1.3602
# 1      3095.78      2465.14    2230.4222    1463.6606       0.8294
# 2      2932.61      2559.94    2186.4111    1698.0172       1.5102
# 3      2988.72      2479.90    2199.0333     909.7926       1.3204
# 4      3032.24      2502.87    2233.3667    1326.5200       1.5334
# 5      2946.25      2432.84    2233.3667    1326.5200       1.5334
# 6      3030.27      2430.12    2230.4222    1463.6606       0.8294
# ...
